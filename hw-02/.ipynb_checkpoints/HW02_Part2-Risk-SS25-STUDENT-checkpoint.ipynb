# %% [markdown]
# # Homework Assignment 2
#
# ## Risk Graph
#
# ### (Notebook 2 of 2)

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Anna Davis </p>
# ### <p style="text-align: right;"> &#9989; davis5304</p>

# %% [markdown]
# ## Assignment Overview
#
# In this assignment, we'll explore graphs using the board game Risk as our practical example. Risk is a strategy game played on a world map where territories are connected to their neighbors. This makes it a perfect candidate for graph representation and analysis.
#
# ### Learning Objectives
#
# - Implement a graph representation of a real-world game board
# - practice using networkx
# - do some research
# - visualize graph data using NetworkX
#
# The assignment is split into two notebooks:
# - Notebook 1 of 2 is worth **14 + 33 + 3 = 51 points**
# - Notebook 2 of 2 is worth **1+ 42 + 1 = 44 points**
# for a total of **95 points**. Point values for each part are included in the section headers and question prompts.
#
# **This assignment is due at 11:59 pm on Friday, March 21st.** It should be uploaded into the "Homework Assignments" submission folder for Homework #2 on D2L.  Submission instructions can be found at the end of the notebook. **You must also fill out a survey regarding this assignment.** The link to this survey can also be found at the end of the notebook.
#
# ---
# ## &#128721; STOP
# **Pause to add this file and commit your changes to your Git repository! (1 points)**
#
# ---

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# <a id="part3"></a>
# [Back to ToC](#toc)
#
# ## Part 3: Creating the Risk Game Graph (42 points)
#
#
# ![image](https://cf.geekdo-images.com/JM6hEipDwIByZKEIK9Dgeg__imagepage/img/OEl2gaJbUxdvIv6tNPzDsQyLUtQ=/fit-in/900x600/filters:no_upscale():strip_icc()/pic365731.jpg)
#
#
# &#9989; **Question 3.1 (5 points)**: Create a dictionary that defines the territories in Risk, organized by continents. Each territory should include its neighboring territories. Use the image above for completing the code below

# %%
# Define the Risk board territories and their connections
risk_territories = {
    'North America': {
        'Alaska': ['Northwest Territory', 'Alberta', 'Kamchatka'],
        'Northwest Territory': ['Alaska', 'Alberta', 'Greenland'],
        'Greenland': ['Northwest Territory', 'Ontario', 'Quebec', 'Iceland'],
        'Alberta': ['Alaska', 'Northwest Territory', 'Ontario', 'Western United States'],
        'Ontario': ['Alberta', 'Northwest Territory', 'Greenland', 'Quebec', 'Western United States', 'Eastern United States'],
        'Quebec': ['Ontario', 'Greenland', 'Eastern United States'],
        'Western United States': ['Alberta', 'Ontario', 'Eastern United States', 'Central America'],
        'Eastern United States': ['Western United States', 'Ontario', 'Quebec', 'Central America'],
        'Central America': ['Western United States', 'Eastern United States', 'Venezuela']
    },
    'South America': {
        'Venezuela': ['Brazil', 'Peru', 'Central America'],
        'Peru': ['Brazil', 'Venezuela', 'Argentina'],
        'Argentina': ['Peru', 'Brazil'],
        'Brazil': ['Venezuela', 'Peru', 'Argentina', 'North Africa']
    },
    'Europe': {
        'Iceland': ['Greenland', 'Great Britain', 'Scandinavia'],
        'Great Britain': ['Iceland', 'Scandinavia', 'Western Europe', 'Northern Europe'],
        'Western Europe': ['Great Britain', 'Northern Europe', 'Southern Europe', 'North Africa'],
        'Northern Europe': ['Great Britain', 'Scandinavia', 'Southern Europe', 'Ukraine'],
        'Southern Europe': ['Western Europe', 'Northern Europe', 'Ukraine', 'North Africa', 'Egypt', 'Middle East'],
        'Ukraine': ['Scandinavia', 'Northern Europe', 'Southern Europe', 'Middle East', 'Afghanistan', 'Ural'],
        'Scandinavia': ['Ukraine', 'Northern Europe', 'Great Britain', 'Iceland']
    },
    'Africa': {
        'North Africa': ['Western Europe', 'Southern Europe', 'Egypt', 'East Africa', 'Congo', 'Brazil'],
        'Egypt': ['Southern Europe', 'Middle East', 'East Africa', 'Congo', 'North Africa'],
        'East Africa': ['Madagascar', 'Congo', 'North Africa', 'Egypt', 'Middle East'],
        'Congo': ['North Africa', 'East Africa', 'South Africa'],
        'South Africa': ['Madagascar', 'East Africa', 'Congo'],
        'Madagascar': ['South Africa', 'East Africa']
    },
    'Asia': {
        'Middle East': ['Egypt', 'Southern Europe', 'East Africa', 'Ukraine', 'Afghanistan', 'India'],
        'India': ['Middle East', 'Afghanistan', 'China', 'Siam'],
        'Siam': ['India', 'China', 'Indonesia'],
        'China': ['Siam', 'India', 'Afghanistan', 'Ural', 'Siberia', 'Mongolia'],
        'Afghanistan': ['Middle East', 'Ukraine', 'India', 'China', 'Ural'],
        'Ural': ['Ukraine', 'Afghanistan', 'China', 'Siberia'],
        'Siberia': ['Ural', 'China', 'Mongolia', 'Irkutsk', 'Yakutsk'],
        'Mongolia': ['Japan', 'Kamchatka', 'Irkutsk', 'Siberia', 'China'],
        'Irkutsk': ['Kamchatka', 'Yakutsk', 'Siberia', 'Mongolia'],
        'Yakutsk': ['Siberia', 'Irkutsk', 'Kamchatka'],
        'Kamchatka': ['Alaska', 'Yakutsk', 'Mongolia', 'Irkutsk', 'Japan'],
        'Japan': ['Kamchatka', 'Mongolia']
    },
    'Australia': {
        'Indonesia': ['Siam', 'New Guinea', 'Western Australia'],
        'New Guinea': ['Indonesia', 'Western Australia', 'Eastern Australia'],
        'Western Australia': ['Indonesia', 'New Guinea', 'Eastern Australia'],
        'Eastern Australia': ['New Guinea', 'Western Australia']
    }
}

# %% [markdown]
# ### Graph Creation
#
# &#9989; **Question 3.2 (7 points)**: Create a NetworkX graph object from the territory definitions. The territories are the nodes of the graph. Implement a function that builds the graph and adds appropriate attributes for continents. _Hint:_ Look up the documentation of `add_node`, what are the possible inputs? Don't forget to connect each territory to its neighbors. Make sure to add plenty of comments in your code.

# %%
def create_risk_graph(territories):
    """
    Create a NetworkX graph from the Risk territory definitions.
    
    Parameters:
        territories (dict): Dictionary containing territory and connection information
        
    Returns:
        G (nx.Graph): NetworkX graph representing the Risk board
    """
    G = nx.Graph()

    for continent, territory_dict in territories.items():
        for territory, neighbors in territory_dict.items():
            G.add_node(territory, continent=continent)
            for neighbor in neighbors:
                G.add_edge(territory, neighbor)
    
    return G

# Create the graph
G = create_risk_graph(risk_territories)

# %% [markdown]
# ### Graph Visualization
#
# &#9989; **Question 3.3 (4 points)**: Create a visualization of the Risk board graph. You can use AI to help you with this. The function below should:
#
# - make a plot of the risk graph.
# - color nodes by continent
# - allow the user to choose a type of layout. _Hint:_ search networkx documentation for the possible layout. Min 5 layouts should be available.
# - print the name of each territory on the respective node
# - make a legend for the graph
# - have very descriptive comments
# - increase the size of each node from the default value
# - increase the font size of label from the default value

# %%
def visualize_risk_graph(G):
    """
    Create a visualization of the Risk board graph with continents colored differently.
    
    Parameters:
        G (nx.Graph): NetworkX graph of the Risk board
    """
    layout_options = { #from chatGPT up until pos = layout_options
        "spring": nx.spring_layout,  # Force-directed layout
        "kamada_kawai": nx.kamada_kawai_layout,  # Energy-based layout
        "circular": nx.circular_layout,  # Arranges nodes in a circle
        "random": nx.random_layout,  # Random positioning
        "spectral": nx.spectral_layout  # Uses graph spectrum for positioning
    }

    print("Choose a layout from the following options:")
    for key in layout_options.keys():
        print(f"- {key}")
    
    layout_choice = input("Enter layout type: ").strip().lower()

    if layout_choice not in layout_options:
        print("Invalid choice, defaulting to 'spring' layout.")
        layout_choice = "spring"

    pos = layout_options[layout_choice](G)

    continents = list(set(nx.get_node_attributes(G, 'continent').values()))
    index = {continent: i for i, continent in enumerate(continents)}

    cmap = plt.colormaps['PuBuGn']

    node_colors = [cmap(index[G.nodes[node]['continent']] / max(1, len(continents) - 1)) for node in G.nodes]

    plt.figure(figsize=(12, 8))
    nx.draw(G, pos, node_color=node_colors, with_labels=True,
            labels={node: node for node in G.nodes}, node_size=1250, font_size=8)

    for i, continent in enumerate(continents):
        plt.scatter([], [], color=cmap(i / max(1, len(continents) - 1)), label=continent)
    plt.legend(title='Continents', loc='best')
    plt.title('risk board graph')

visualize_risk_graph(G)

#OpenAI. (2025). ChatGPT-4.0. Accessed from https://chat.openai.com/ on Mar 21, 2025. 
#Prompt chain:{‘how can I create a visualization of a game board that allows the user 
#to choose a type of layout, provide examples from networkx.’}
#OpenAI. (2025). ChatGPT-4.0. Accessed from https://chat.openai.com/ on Mar 21, 2025. 
#Prompt chain:{‘how can I create a legend given a colormap and a nx.draw()’}
# Out:
# Choose a layout from the following options:
# - spring
# - kamada_kawai
# - circular
# - random
# - spectral
# Enter layout type:  kamada_kawai

# %% [markdown]
# &#9989; **Question 3.4 (26 points)**: Answer the following questions based on the Risk board graph visualization. Each answer should have a minimum of 1-2 sentences and snippet of the code that supports your answer. You must explain what each function in the code snippet does.
#
# All answers should be in the same markdown cell.
#
# The code snippet should be properly displayed using code markdown.
#
# 1. Which layout type provides the best visualization of the continent-based clustering in the Risk board graph?
#     - Explain the rationale behind your choice of layout.
# 2. Do a little research and explain what the Kamada-Kawai layout does? Make sure to cite your sources.
# 3. Which part of the code is used to assign the color of each node based on its continent?
# 4. How did you make the legend? Explain any non-obvious part of the code.
# 5. What colormap did you choose for the continents and how did you import the colormap?
# 6. How did you set the node size and font size in the visualization?
# 7. How did you print the labels for the nodes?

# %% [markdown]
# ✎
# 1. The kamada_kawai provides the best visualization of the continent-based clustering in the risk board graph. The other options have either clumped together nodes or the lines ar a jumbled mess. The "spring": nx.spring_layout, is meant to decrease edge crossing but ends up greatly increasing the clustering of the nodes. "circular": nx.circular_layout, arranges nodes in a circle overall making the lines connecting the nodes hard to decipher. "random": nx.random_layout,  is unpredictable and typically results in a knot of data."spectral": nx.spectral_layout uses a graph spectrum for positioning the nodes which may work well for some data but again results in jumbled nodes and crossed lines. The kamada_kawai visualization provides a model with none of those problems.
# 2. According to NetworkX.org, kamada-kawai layout is a 'force-directed graph layout algorithm.' Meaning it acts as if the nodes are connected by springs, to keep distance proportional to the shortest path. It also minimizes edge crossing. source: Networkx.org, 3/21/2025, https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.kamada_kawai_layout.html
# 3.    continents = list(set(nx.get_node_attributes(G, 'continent').values()))
#     index = {continent: i for i, continent in enumerate(continents)}
#    cmap = plt.colormaps['PuBuGn']
#     node_colors = [cmap(index[G.nodes[node]['continent']] / max(1, len(continents) - 1)) for node in G.nodes]
#     this portion of the code assigns colors and applies the colors map. As you can see I seperated the indeci of the continents and the continents in order to correctly apply the colormap.
# 4.     for i, continent in enumerate(continents):
#         plt.scatter([], [], color=cmap(i / max(1, len(continents) - 1)), label=continent)
#     plt.legend(title='Continents', loc='best')
#    this is the code I used for the legend. I used chatgpt for it as I didnt fully understand how to make it from the data given. However, after research i learn that using the first line it moves through the continents, adds each to an invisible scatter plot, and esentually adds that to a legend.
# 6.     nx.draw(G, pos, node_color=node_colors, with_labels=True,
#             labels={node: node for node in G.nodes}, node_size=1250, font_size=8)
#    i set the node and font size in this portion of the code. I started node at 1000 and just kept working up by 50 until I felt it was large enough. The font size I started off at 10 and decreased by one until I felt it was legible and also fitting for the size requirements.
# 7.     nx.draw(G, pos, node_color=node_colors, with_labels=True,
#             labels={node: node for node in G.nodes}, node_size=1250, font_size=8)
#     i looked up the contents of nx.draw and found that with_labels=True would print off the nodes with labels. That is how I got the labels.

# %% [markdown]
# ---
# ## &#128721; STOP
# **Pause to commit your changes to your Git repository! (1 points)**
#
# Take a moment to save your notebook, commit the changes to your Git repository using the commit message "**Committing Part 3**", no need to push the changes to GitHub yet, but you can if you want.

# %% [markdown]
# ---
# ## Assignment wrap-up
#
# Please fill out the form that appears when you run the code below.  **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://forms.office.com/r/mB0YjLYvAA" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.office.com/r/mB0YjLYvAA"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ### Congratulations, you're done!
#
# If you like, you can upload this file to D2L for a record. Nevertheless, **we will grade the copy on GitHub**.

# %% [markdown]
# &#169; Copyright 2025,  Department of Computational Mathematics, Science and Engineering at Michigan State University
